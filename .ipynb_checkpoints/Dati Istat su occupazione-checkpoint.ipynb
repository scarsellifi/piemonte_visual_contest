# %%
import os
import pandas as pd
import zipfile

# %%
dati = pd.read_csv(, sep="|", engine = "python")

# %%
z = zipfile.ZipFile(os.path.join("E:\FILE TEMPORANEI", "DCCV_OCCUPATIT -  Employment                                 - Full dataset.gz"))
df_dati = pd.read_csv(z.open("DCCV_OCCUPATIT_Data+FootnotesLegend_175b2401-3654-4673-9e60-b300989088bb.csv"), sep="|", engine = "python")
# Out:
#                    TER                                          Territory  \
# 0                   IT                                              Italy
# 1                   IT                                              Italy
# 2                   IT                                              Italy
# 3                   IT                                              Italy
# 4                   IT                                              Italy
# 5                   IT                                              Italy
# 6                   IT                                              Italy
# 7                   IT                                              Italy
# 8                   IT                                              Italy
# 9                   IT                                              Italy
# 10                  IT                                              Italy
# 11                  IT                                              Italy
# ...
